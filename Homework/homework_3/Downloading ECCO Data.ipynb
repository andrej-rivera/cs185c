# %% [markdown]
# # Downloading ECCO Data
#
# Author: Mike Wood
#
# This notebook is designed to download ECCO data from the [ECCO Drive](https://ecco.jpl.nasa.gov/drive/).
#
# Note that you must have a [NASA Earthdata](https://www.earthdata.nasa.gov/) account. If you don't already have one, be sure to make one before using this notebook.
#
# When you first navigate to the [ECCO Drive](https://ecco.jpl.nasa.gov/drive/), you will be directed to a page with your WebDAV/Programmatic API credentials - these will be used when prompted for your credentials below.
#
# #### Import the modules for this notebook

# %%
import requests
import calendar
from requests.auth import HTTPBasicAuth
import os

# %% [markdown]
# #### Define the destination file path

# %%
# define the path to the folder where the data will be downloaded
download_folder = 'C:\\Users\\Andre\\Desktop\\Classwork\\cs185c\\data\\ECCO'

# %% [markdown]
# #### Define the data request

# %%
# choose an ECCO version and release
version = 'Version5' #e.g. Version4
release = 'Alpha' #e.g. Release4

# choose a subset
subset = 'latlon_daily' #e.g. interp_monthly

# choose the variable to download
var_name = 'SST' # e.g. SSHDYN

# choose a start year and end year (in range 1992-2017)
start_year = 2015
end_year = 2015

# %% [markdown]
# #### Make a list of file paths
# Nothing to do here - just run this cell to generate the list.

# %%
# define the base url
base_url = 'https://ecco.jpl.nasa.gov/drive/files/'+version+'/'+release+'/'+subset+'/'+var_name+".nc"

# make a list of URls corresponding to the file dates
file_urls = []
for year in range(start_year,end_year+1):
    for month in range(1,13):
        for day in range(1, calendar.monthrange(year,month)[1]):
            yr = str(year)
            mo = '{:02d}'.format(month)
            da = '{:02d}'.format(day)
            file_name = var_name+'_'+yr+''+mo+''+da+'.nc'
            file_urls.append(base_url+'/'+file_name)

# %% [markdown]
# #### Download the data

# %%
print('Enter your WebDAV/Programmatic API credentials')
username = input('Enter your username: ') # andrejosh
password = input('Enter your password: ') # lDCOlIewR49T5Wkw2jo

# check that all of the subdirectories are created
if version not in os.listdir(download_folder):
    os.mkdir(os.path.join(download_folder,version))
if release not in os.listdir(os.path.join(download_folder,version)):
    os.mkdir(os.path.join(download_folder,version,release))
if subset not in os.listdir(os.path.join(download_folder,version,release)):
    os.mkdir(os.path.join(download_folder,version,release,subset))
if var_name not in os.listdir(os.path.join(download_folder,version,release,subset)):
    os.mkdir(os.path.join(download_folder,version,release,subset,var_name))

# download all of the data
for i in range(len(file_urls)):
    url = file_urls[i]
    file_name = url.split('/')[-1]
    if file_name not in os.listdir(os.path.join(download_folder,version,release,subset,var_name)):
        print('Downloading '+file_name+' (file '+str(i+1)+' of '+str(len(file_urls))+')')
        output_file = os.path.join(download_folder,version,release,subset,var_name,file_name)
        with requests.get(url, stream=True, allow_redirects=True, auth=HTTPBasicAuth(username, password)) as r:
            r.raise_for_status()
            with open(output_file, 'wb') as f:                   
                for chunk in r.iter_content(chunk_size=8192):   
                    f.write(chunk)
# Out:
# Enter your WebDAV/Programmatic API credentials
# Enter your username:  andrejosh
# Enter your password:  lDCOlIewR49T5Wkw2jo
# Downloading SST_20150101.nc (file 1 of 353)
# Downloading SST_20150102.nc (file 2 of 353)
# Downloading SST_20150103.nc (file 3 of 353)
# Downloading SST_20150104.nc (file 4 of 353)
# Downloading SST_20150105.nc (file 5 of 353)
# Downloading SST_20150106.nc (file 6 of 353)
# Downloading SST_20150107.nc (file 7 of 353)
# Downloading SST_20150108.nc (file 8 of 353)
# Downloading SST_20150109.nc (file 9 of 353)
# Downloading SST_20150110.nc (file 10 of 353)
# Downloading SST_20150111.nc (file 11 of 353)
# Downloading SST_20150112.nc (file 12 of 353)
# Downloading SST_20150113.nc (file 13 of 353)
# Downloading SST_20150114.nc (file 14 of 353)
# Downloading SST_20150115.nc (file 15 of 353)
# Downloading SST_20150116.nc (file 16 of 353)
# Downloading SST_20150117.nc (file 17 of 353)
# Downloading SST_20150118.nc (file 18 of 353)
# Downloading SST_20150119.nc (file 19 of 353)
# Downloading SST_20150120.nc (file 20 of 353)
# Downloading SST_20150121.nc (file 21 of 353)
# Downloading SST_20150122.nc (file 22 of 353)
# Downloading SST_20150123.nc (file 23 of 353)
# Downloading SST_20150124.nc (file 24 of 353)
# Downloading SST_20150125.nc (file 25 of 353)
# Downloading SST_20150126.nc (file 26 of 353)
# Downloading SST_20150127.nc (file 27 of 353)
# Downloading SST_20150128.nc (file 28 of 353)
# Downloading SST_20150129.nc (file 29 of 353)
# Downloading SST_20150130.nc (file 30 of 353)
# Downloading SST_20150201.nc (file 31 of 353)
# Downloading SST_20150202.nc (file 32 of 353)
# Downloading SST_20150203.nc (file 33 of 353)
# Downloading SST_20150204.nc (file 34 of 353)
# Downloading SST_20150205.nc (file 35 of 353)
# Downloading SST_20150206.nc (file 36 of 353)
# Downloading SST_20150207.nc (file 37 of 353)
# Downloading SST_20150208.nc (file 38 of 353)
# Downloading SST_20150209.nc (file 39 of 353)
# Downloading SST_20150210.nc (file 40 of 353)
# Downloading SST_20150211.nc (file 41 of 353)
# Downloading SST_20150212.nc (file 42 of 353)
# Downloading SST_20150213.nc (file 43 of 353)
# Downloading SST_20150214.nc (file 44 of 353)
# Downloading SST_20150215.nc (file 45 of 353)
# Downloading SST_20150216.nc (file 46 of 353)
# Downloading SST_20150217.nc (file 47 of 353)
# Downloading SST_20150218.nc (file 48 of 353)
# Downloading SST_20150219.nc (file 49 of 353)
# Downloading SST_20150220.nc (file 50 of 353)
# Downloading SST_20150221.nc (file 51 of 353)
# Downloading SST_20150222.nc (file 52 of 353)
# Downloading SST_20150223.nc (file 53 of 353)
# Downloading SST_20150224.nc (file 54 of 353)
# Downloading SST_20150225.nc (file 55 of 353)
# Downloading SST_20150226.nc (file 56 of 353)
# Downloading SST_20150227.nc (file 57 of 353)
# Downloading SST_20150301.nc (file 58 of 353)
# Downloading SST_20150302.nc (file 59 of 353)
# Downloading SST_20150303.nc (file 60 of 353)
# Downloading SST_20150304.nc (file 61 of 353)
# Downloading SST_20150305.nc (file 62 of 353)
# Downloading SST_20150306.nc (file 63 of 353)
# Downloading SST_20150307.nc (file 64 of 353)
# Downloading SST_20150308.nc (file 65 of 353)
# Downloading SST_20150309.nc (file 66 of 353)
# Downloading SST_20150310.nc (file 67 of 353)
# Downloading SST_20150311.nc (file 68 of 353)
# Downloading SST_20150312.nc (file 69 of 353)
# Downloading SST_20150313.nc (file 70 of 353)
# Downloading SST_20150314.nc (file 71 of 353)
# Downloading SST_20150315.nc (file 72 of 353)
# Downloading SST_20150316.nc (file 73 of 353)
# Downloading SST_20150317.nc (file 74 of 353)
# Downloading SST_20150318.nc (file 75 of 353)
# Downloading SST_20150319.nc (file 76 of 353)
# Downloading SST_20150320.nc (file 77 of 353)
# Downloading SST_20150321.nc (file 78 of 353)
# Downloading SST_20150322.nc (file 79 of 353)
# Downloading SST_20150323.nc (file 80 of 353)
# Downloading SST_20150324.nc (file 81 of 353)
# Downloading SST_20150325.nc (file 82 of 353)
# Downloading SST_20150326.nc (file 83 of 353)
# Downloading SST_20150327.nc (file 84 of 353)
# Downloading SST_20150328.nc (file 85 of 353)
# Downloading SST_20150329.nc (file 86 of 353)
# Downloading SST_20150330.nc (file 87 of 353)
# Downloading SST_20150401.nc (file 88 of 353)
# Downloading SST_20150402.nc (file 89 of 353)
# Downloading SST_20150403.nc (file 90 of 353)
# Downloading SST_20150404.nc (file 91 of 353)
# Downloading SST_20150405.nc (file 92 of 353)
# Downloading SST_20150406.nc (file 93 of 353)
# Downloading SST_20150407.nc (file 94 of 353)
# Downloading SST_20150408.nc (file 95 of 353)
# Downloading SST_20150409.nc (file 96 of 353)
# Downloading SST_20150410.nc (file 97 of 353)
# Downloading SST_20150411.nc (file 98 of 353)
# Downloading SST_20150412.nc (file 99 of 353)
# Downloading SST_20150413.nc (file 100 of 353)
# Downloading SST_20150414.nc (file 101 of 353)
# Downloading SST_20150415.nc (file 102 of 353)
# Downloading SST_20150416.nc (file 103 of 353)
# Downloading SST_20150417.nc (file 104 of 353)
# Downloading SST_20150418.nc (file 105 of 353)
# Downloading SST_20150419.nc (file 106 of 353)
# Downloading SST_20150420.nc (file 107 of 353)
# Downloading SST_20150421.nc (file 108 of 353)
# Downloading SST_20150422.nc (file 109 of 353)
# Downloading SST_20150423.nc (file 110 of 353)
# Downloading SST_20150424.nc (file 111 of 353)
# Downloading SST_20150425.nc (file 112 of 353)
# Downloading SST_20150426.nc (file 113 of 353)
# Downloading SST_20150427.nc (file 114 of 353)
# Downloading SST_20150428.nc (file 115 of 353)
# Downloading SST_20150429.nc (file 116 of 353)
# Downloading SST_20150501.nc (file 117 of 353)
# Downloading SST_20150502.nc (file 118 of 353)
# Downloading SST_20150503.nc (file 119 of 353)
# Downloading SST_20150504.nc (file 120 of 353)
# Downloading SST_20150505.nc (file 121 of 353)
# Downloading SST_20150506.nc (file 122 of 353)
# Downloading SST_20150507.nc (file 123 of 353)
# Downloading SST_20150508.nc (file 124 of 353)
# Downloading SST_20150509.nc (file 125 of 353)
# Downloading SST_20150510.nc (file 126 of 353)
# Downloading SST_20150511.nc (file 127 of 353)
# Downloading SST_20150512.nc (file 128 of 353)
# Downloading SST_20150513.nc (file 129 of 353)
# Downloading SST_20150514.nc (file 130 of 353)
# Downloading SST_20150515.nc (file 131 of 353)
# Downloading SST_20150516.nc (file 132 of 353)
# Downloading SST_20150517.nc (file 133 of 353)
# Downloading SST_20150518.nc (file 134 of 353)
# Downloading SST_20150519.nc (file 135 of 353)
# Downloading SST_20150520.nc (file 136 of 353)
# Downloading SST_20150521.nc (file 137 of 353)
# Downloading SST_20150522.nc (file 138 of 353)
# Downloading SST_20150523.nc (file 139 of 353)
# Downloading SST_20150524.nc (file 140 of 353)
# Downloading SST_20150525.nc (file 141 of 353)
# Downloading SST_20150526.nc (file 142 of 353)
# Downloading SST_20150527.nc (file 143 of 353)
# Downloading SST_20150528.nc (file 144 of 353)
# Downloading SST_20150529.nc (file 145 of 353)
# Downloading SST_20150530.nc (file 146 of 353)
# Downloading SST_20150601.nc (file 147 of 353)
# Downloading SST_20150602.nc (file 148 of 353)
# Downloading SST_20150603.nc (file 149 of 353)
# Downloading SST_20150604.nc (file 150 of 353)
# Downloading SST_20150605.nc (file 151 of 353)
# Downloading SST_20150606.nc (file 152 of 353)
# Downloading SST_20150607.nc (file 153 of 353)
# Downloading SST_20150608.nc (file 154 of 353)
# Downloading SST_20150609.nc (file 155 of 353)
# Downloading SST_20150610.nc (file 156 of 353)
# Downloading SST_20150611.nc (file 157 of 353)
# Downloading SST_20150612.nc (file 158 of 353)
# Downloading SST_20150613.nc (file 159 of 353)
# Downloading SST_20150614.nc (file 160 of 353)
# Downloading SST_20150615.nc (file 161 of 353)
# Downloading SST_20150616.nc (file 162 of 353)
# Downloading SST_20150617.nc (file 163 of 353)
# Downloading SST_20150618.nc (file 164 of 353)
# Downloading SST_20150619.nc (file 165 of 353)
# Downloading SST_20150620.nc (file 166 of 353)
# Downloading SST_20150621.nc (file 167 of 353)
# Downloading SST_20150622.nc (file 168 of 353)
# Downloading SST_20150623.nc (file 169 of 353)
# Downloading SST_20150624.nc (file 170 of 353)
# Downloading SST_20150625.nc (file 171 of 353)
# Downloading SST_20150626.nc (file 172 of 353)
# Downloading SST_20150627.nc (file 173 of 353)
# Downloading SST_20150628.nc (file 174 of 353)
# Downloading SST_20150629.nc (file 175 of 353)
# Downloading SST_20150701.nc (file 176 of 353)
# Downloading SST_20150702.nc (file 177 of 353)
# Downloading SST_20150703.nc (file 178 of 353)
# Downloading SST_20150704.nc (file 179 of 353)
# Downloading SST_20150705.nc (file 180 of 353)
# Downloading SST_20150706.nc (file 181 of 353)
# Downloading SST_20150707.nc (file 182 of 353)
# Downloading SST_20150708.nc (file 183 of 353)
# Downloading SST_20150709.nc (file 184 of 353)
# Downloading SST_20150710.nc (file 185 of 353)
# Downloading SST_20150711.nc (file 186 of 353)
# Downloading SST_20150712.nc (file 187 of 353)
# Downloading SST_20150713.nc (file 188 of 353)
# Downloading SST_20150714.nc (file 189 of 353)
# Downloading SST_20150715.nc (file 190 of 353)
# Downloading SST_20150716.nc (file 191 of 353)
# Downloading SST_20150717.nc (file 192 of 353)
# Downloading SST_20150718.nc (file 193 of 353)
# Downloading SST_20150719.nc (file 194 of 353)
# Downloading SST_20150720.nc (file 195 of 353)
# Downloading SST_20150721.nc (file 196 of 353)
# Downloading SST_20150722.nc (file 197 of 353)
# Downloading SST_20150723.nc (file 198 of 353)
# Downloading SST_20150724.nc (file 199 of 353)
# Downloading SST_20150725.nc (file 200 of 353)
# Downloading SST_20150726.nc (file 201 of 353)
# Downloading SST_20150727.nc (file 202 of 353)
# Downloading SST_20150728.nc (file 203 of 353)
# Downloading SST_20150729.nc (file 204 of 353)
# Downloading SST_20150730.nc (file 205 of 353)
# Downloading SST_20150801.nc (file 206 of 353)
# Downloading SST_20150802.nc (file 207 of 353)
# Downloading SST_20150803.nc (file 208 of 353)
# Downloading SST_20150804.nc (file 209 of 353)
# Downloading SST_20150805.nc (file 210 of 353)
# Downloading SST_20150806.nc (file 211 of 353)
# Downloading SST_20150807.nc (file 212 of 353)
# Downloading SST_20150808.nc (file 213 of 353)
# Downloading SST_20150809.nc (file 214 of 353)
# Downloading SST_20150810.nc (file 215 of 353)
# Downloading SST_20150811.nc (file 216 of 353)
# Downloading SST_20150812.nc (file 217 of 353)
# Downloading SST_20150813.nc (file 218 of 353)
# Downloading SST_20150814.nc (file 219 of 353)
# Downloading SST_20150815.nc (file 220 of 353)
# Downloading SST_20150816.nc (file 221 of 353)
# Downloading SST_20150817.nc (file 222 of 353)
# Downloading SST_20150818.nc (file 223 of 353)
# Downloading SST_20150819.nc (file 224 of 353)
# Downloading SST_20150820.nc (file 225 of 353)
# Downloading SST_20150821.nc (file 226 of 353)
# Downloading SST_20150822.nc (file 227 of 353)
# Downloading SST_20150823.nc (file 228 of 353)
# Downloading SST_20150824.nc (file 229 of 353)
# Downloading SST_20150825.nc (file 230 of 353)
# Downloading SST_20150826.nc (file 231 of 353)
# Downloading SST_20150827.nc (file 232 of 353)
# Downloading SST_20150828.nc (file 233 of 353)
# Downloading SST_20150829.nc (file 234 of 353)
# Downloading SST_20150830.nc (file 235 of 353)
# Downloading SST_20150901.nc (file 236 of 353)
# Downloading SST_20150902.nc (file 237 of 353)
# Downloading SST_20150903.nc (file 238 of 353)
# Downloading SST_20150904.nc (file 239 of 353)
# Downloading SST_20150905.nc (file 240 of 353)
# Downloading SST_20150906.nc (file 241 of 353)
# Downloading SST_20150907.nc (file 242 of 353)
# Downloading SST_20150908.nc (file 243 of 353)
# Downloading SST_20150909.nc (file 244 of 353)
# Downloading SST_20150910.nc (file 245 of 353)
# Downloading SST_20150911.nc (file 246 of 353)
# Downloading SST_20150912.nc (file 247 of 353)
# Downloading SST_20150913.nc (file 248 of 353)
# Downloading SST_20150914.nc (file 249 of 353)
# Downloading SST_20150915.nc (file 250 of 353)
# Downloading SST_20150916.nc (file 251 of 353)
# Downloading SST_20150917.nc (file 252 of 353)
# Downloading SST_20150918.nc (file 253 of 353)
# Downloading SST_20150919.nc (file 254 of 353)
# Downloading SST_20150920.nc (file 255 of 353)
# Downloading SST_20150921.nc (file 256 of 353)
# Downloading SST_20150922.nc (file 257 of 353)
# Downloading SST_20150923.nc (file 258 of 353)
# Downloading SST_20150924.nc (file 259 of 353)
# Downloading SST_20150925.nc (file 260 of 353)
# Downloading SST_20150926.nc (file 261 of 353)
# Downloading SST_20150927.nc (file 262 of 353)
# Downloading SST_20150928.nc (file 263 of 353)
# Downloading SST_20150929.nc (file 264 of 353)
# Downloading SST_20151001.nc (file 265 of 353)
# Downloading SST_20151002.nc (file 266 of 353)
# Downloading SST_20151003.nc (file 267 of 353)
# Downloading SST_20151004.nc (file 268 of 353)
# Downloading SST_20151005.nc (file 269 of 353)
# Downloading SST_20151006.nc (file 270 of 353)
# Downloading SST_20151007.nc (file 271 of 353)
# Downloading SST_20151008.nc (file 272 of 353)
# Downloading SST_20151009.nc (file 273 of 353)
# Downloading SST_20151010.nc (file 274 of 353)
# Downloading SST_20151011.nc (file 275 of 353)
# Downloading SST_20151012.nc (file 276 of 353)
# Downloading SST_20151013.nc (file 277 of 353)
# Downloading SST_20151014.nc (file 278 of 353)
# Downloading SST_20151015.nc (file 279 of 353)
# Downloading SST_20151016.nc (file 280 of 353)
# Downloading SST_20151017.nc (file 281 of 353)
# Downloading SST_20151018.nc (file 282 of 353)
# Downloading SST_20151019.nc (file 283 of 353)
# Downloading SST_20151020.nc (file 284 of 353)
# Downloading SST_20151021.nc (file 285 of 353)
# Downloading SST_20151022.nc (file 286 of 353)
# Downloading SST_20151023.nc (file 287 of 353)
# Downloading SST_20151024.nc (file 288 of 353)
# Downloading SST_20151025.nc (file 289 of 353)
# Downloading SST_20151026.nc (file 290 of 353)
# Downloading SST_20151027.nc (file 291 of 353)
# Downloading SST_20151028.nc (file 292 of 353)
# Downloading SST_20151029.nc (file 293 of 353)
# Downloading SST_20151030.nc (file 294 of 353)
# Downloading SST_20151101.nc (file 295 of 353)
# Downloading SST_20151102.nc (file 296 of 353)
# Downloading SST_20151103.nc (file 297 of 353)
# Downloading SST_20151104.nc (file 298 of 353)
# Downloading SST_20151105.nc (file 299 of 353)
# Downloading SST_20151106.nc (file 300 of 353)
# Downloading SST_20151107.nc (file 301 of 353)
# Downloading SST_20151108.nc (file 302 of 353)
# Downloading SST_20151109.nc (file 303 of 353)
# Downloading SST_20151110.nc (file 304 of 353)
# Downloading SST_20151111.nc (file 305 of 353)
# Downloading SST_20151112.nc (file 306 of 353)
# Downloading SST_20151113.nc (file 307 of 353)
# Downloading SST_20151114.nc (file 308 of 353)
# Downloading SST_20151115.nc (file 309 of 353)
# Downloading SST_20151116.nc (file 310 of 353)
# Downloading SST_20151117.nc (file 311 of 353)
# Downloading SST_20151118.nc (file 312 of 353)
# Downloading SST_20151119.nc (file 313 of 353)
# Downloading SST_20151120.nc (file 314 of 353)
# Downloading SST_20151121.nc (file 315 of 353)
# Downloading SST_20151122.nc (file 316 of 353)
# Downloading SST_20151123.nc (file 317 of 353)
# Downloading SST_20151124.nc (file 318 of 353)
# Downloading SST_20151125.nc (file 319 of 353)
# Downloading SST_20151126.nc (file 320 of 353)
# Downloading SST_20151127.nc (file 321 of 353)
# Downloading SST_20151128.nc (file 322 of 353)
# Downloading SST_20151129.nc (file 323 of 353)
# Downloading SST_20151201.nc (file 324 of 353)
# Downloading SST_20151202.nc (file 325 of 353)
# Downloading SST_20151203.nc (file 326 of 353)
# Downloading SST_20151204.nc (file 327 of 353)
# Downloading SST_20151205.nc (file 328 of 353)
# Downloading SST_20151206.nc (file 329 of 353)
# Downloading SST_20151207.nc (file 330 of 353)
# Downloading SST_20151208.nc (file 331 of 353)
# Downloading SST_20151209.nc (file 332 of 353)
# Downloading SST_20151210.nc (file 333 of 353)
# Downloading SST_20151211.nc (file 334 of 353)
# Downloading SST_20151212.nc (file 335 of 353)
# Downloading SST_20151213.nc (file 336 of 353)
# Downloading SST_20151214.nc (file 337 of 353)
# Downloading SST_20151215.nc (file 338 of 353)
# Downloading SST_20151216.nc (file 339 of 353)
# Downloading SST_20151217.nc (file 340 of 353)
# Downloading SST_20151218.nc (file 341 of 353)
# Downloading SST_20151219.nc (file 342 of 353)
# Downloading SST_20151220.nc (file 343 of 353)
# Downloading SST_20151221.nc (file 344 of 353)
# Downloading SST_20151222.nc (file 345 of 353)
# Downloading SST_20151223.nc (file 346 of 353)
# Downloading SST_20151224.nc (file 347 of 353)
# Downloading SST_20151225.nc (file 348 of 353)
# Downloading SST_20151226.nc (file 349 of 353)
# Downloading SST_20151227.nc (file 350 of 353)
# Downloading SST_20151228.nc (file 351 of 353)
# Downloading SST_20151229.nc (file 352 of 353)
# Downloading SST_20151230.nc (file 353 of 353)

# %% [markdown]
# Note: if the above cell fails before the download is complete, try re-running - often the API will reject downloads when there are too many pings in a given time interval.
